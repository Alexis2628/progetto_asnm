# %%
import requests
import json

def retrieve_follower(ti,  user_id: str) -> dict:

        session = requests.Session()
        session.headers.update({
            "authority": "www.threads.net",
            "method": "POST",
            "path": "/graphql/query",
            "scheme": "https",
            "accept": "*/*",
            "accept-encoding": "gzip, deflate, br",
            "accept-language": "it,it-IT;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6",
            "origin": "https://www.threads.net",
            "priority": "u=1, i",
            "referer": "https://www.threads.net/",
            "x-ig-app-id": "238260118697367",
            "Content-Type": "application/json"
        })
        cookies = {
            # "sessionid": "65955050144%3AS1xuKkl6W1kKqB%3A23%3AAYcjBamMFOs7TY1uYVsrP-gAou7-TriJJsp8l1NgLA"
            # "sessionid": "71441509544%3Aj1PUAfk9VWSoPS%3A29%3AAYegZHsr4t98FTJhtWIDRsGm-00AY5RC_xH7YHaNFg"
            "sessionid": "71441509544%3AbPWmQfLc5vQhzF%3A7%3AAYfgsFzvtyS88WCjLlPNxUHfxAyfSs-PMk0cunbBMA"
        }
        session.cookies.update(cookies)

        data={
                'lsd': ti.api_token,
                "fb_api_req_friendly_name": "BarcelonaFriendshipsFollowersTabQuery",
                "fb_api_caller_class": "RelayModern",
                "__comet_req": 29,
                'variables':json.dumps({
                    "first": 100,
                    "userID": user_id,
                    "__relay_internal__pv__BarcelonaIsLoggedInrelayprovider": True,
                    "__relay_internal__pv__BarcelonaIsCrawlerrelayprovider": False,
                    "__relay_internal__pv__BarcelonaHasDisplayNamesrelayprovider":False,
                    "__relay_internal__pv__BarcelonaShouldShowFediverseListsrelayprovider": True
                    #"__relay_internal__pv__BarcelonaIsInlineReelsEnabledrelayprovider" : False
                }),
                'doc_id': "9390748034302491" #"8556216414475236",#'26277468955231937',
            }


        response = session.post("https://www.threads.net/graphql/query", data=data)
        
        return response.json()

from threads_interface import ThreadsInterface
ti = ThreadsInterface()
retrieve_follower(ti, "194317179")
# Out:
# {'errors': [{'message': 'execution error', 'severity': 'CRITICAL'}],
#  'status': 'ok'}

# %%
len(data["data"]["user"]["followers"]["edges"])
# Out:
# 50

# %%
# Out:
# {'data': {'user': {'followers': {'edges': [{'node': {'pk': '53633710009',
#        'text_post_app_is_private': True,
#        'friendship_status': {'followed_by': False,
#         'following': False,
#         'outgoing_request': False,
#         'text_post_app_pre_following': False},
#        'profile_pic_url': 'https://instagram.fsuf1-2.fna.fbcdn.net/v/t51.2885-19/454718466_2004254383357703_857131903462990184_n.jpg?stp=dst-jpg_s150x150_tt6&_nc_ht=instagram.fsuf1-2.fna.fbcdn.net&_nc_cat=111&_nc_ohc=gyy4ICCRn7kQ7kNvgHtW5Nz&_nc_gid=d12be3fca7f54374b09133e5097e2fce&edm=ADWc8IMBAAAA&ccb=7-5&oh=00_AYDqUWEpl7711yYwrrybwsHO1Isp0uKu9VCGSSYwQWFXgg&oe=6779BD90&_nc_sid=fdfae5',
#        'username': 'btch.mf',
#        'follower_count': 1,
#        'profile_context_facepile_users': [],
#        'is_verified': False,
#        'full_name': 'Trixie',
#        'has_onboarded_to_text_post_app': True,
#        'id': '53633710009',
#        '__typename': 'XDTUserDict'},
#       'cursor': None},
# ...

# %%
import requests
import json
def retrieve_thread(ti, thread_id: str) -> dict:
    
        headers = ti.default_headers.copy()
        headers['X-FB-Friendly-Name'] = 'BarcelonaFriendshipsFollowersTabQuery'
        headers["content-type"] = "application/x-www-form-urlencoded"
        headers["Cookie"] = "sessionid=71441509544%3AbPWmQfLc5vQhzF%3A7%3AAYfgsFzvtyS88WCjLlPNxUHfxAyfSs-PMk0cunbBMA"
        response = requests.post(
            url=ti.THREADS_API_URL,
            headers=headers,
            data={
                'lsd': ti.api_token,
                'variables': json.dumps(
                    {
                        "userID":thread_id,
                        "__relay_internal__pv__BarcelonaIsLoggedInrelayprovider":True,
                        "__relay_internal__pv__BarcelonaIsCrawlerrelayprovider": False,
                        "__relay_internal__pv__BarcelonaHasDisplayNamesrelayprovider":False,
                        "__relay_internal__pv__BarcelonaShouldShowFediverseListsrelayprovider": False
                    }
                ),
                'doc_id': '9390748034302491',
            },
        )

        return response.json()

from threads_interface import ThreadsInterface
ti = ThreadsInterface()
retrieve_thread(ti,"71620739742")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Utente\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\Utente\AppData\Local\Programs\Python\Python310\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
import requests
import json
from threads_interface import ThreadsInterface
ti = ThreadsInterface()
def retrieve_follower_by_id2(user_id: str) -> dict:
        
        session = requests.Session()
        session.headers.update({
            "authority": "www.threads.net",
            "method": "POST",
            "path": "/graphql/query",
            "scheme": "https",
            "accept": "*/*",
            "accept-encoding": "gzip, deflate, br",
            "accept-language": "it,it-IT;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6",
            "cache-control": "no-cache",
            "pragma": "no-cache",
            "origin": "https://www.threads.net",
            "priority": "u=1, i",
            "referer": "https://www.threads.net/",
            "x-ig-app-id": "238260118697367",
            "Content-Type": "application/json",
            "x-fb-lsd": ti.api_token,
        })
        cookies = {
            # "sessionid": "65955050144%3AON5GCEKyL8q2Vm%3A3%3AAYeslvZbdMdN-6poBA9OvRTqMIrFnGxFTzOb9HOEyw",
            "sessionid": "71441509544%3AbPWmQfLc5vQhzF%3A7%3AAYfgsFzvtyS88WCjLlPNxUHfxAyfSs-PMk0cunbBMA"
        }
        session.cookies.update(cookies)

        data = {
            'lsd': ti.api_token,
            "fb_api_req_friendly_name": "BarcelonaFriendshipsFollowersTabQuery",
            "fb_api_caller_class": "RelayModern",
            "__comet_req": 29,
            'variables': json.dumps({
                "first": 20,
                "userID": user_id,
                "__relay_internal__pv__BarcelonaIsLoggedInrelayprovider": True,
                "__relay_internal__pv__BarcelonaIsCrawlerrelayprovider": False,
                "__relay_internal__pv__BarcelonaShouldShowFediverseListsrelayprovider": False,
                "__relay_internal__pv__BarcelonaIsInlineReelsEnabledrelayprovider": False
            }),
            'doc_id': "9390748034302491",
        }

        try:
            response = session.post("https://www.threads.net/graphql/query", data=data)
            return response.json()
        except requests.exceptions.RequestException as e:
            # Gestisce errori legati alla richiesta HTTP
            raise RuntimeError(f"HTTP request failed: {e}")
        except json.JSONDecodeError as e:
            # Gestisce errori legati alla decodifica del JSON
            raise RuntimeError(f"Response is not valid JSON: {e}")
retrieve_follower_by_id2(user_id= "69002489097")
# Out:
# {'errors': [{'message': 'execution error', 'severity': 'CRITICAL'}],
#  'status': 'ok'}

# %%
import json
import os
from threads_interface import ThreadsInterface
import logging


# File per memorizzare gli user_id già analizzati
PROCESSED_USERS_FILE = "../data/processed_users.json"

def load_processed_users():
    """Carica gli user_id già analizzati dal file."""
    if os.path.exists(PROCESSED_USERS_FILE):
        try:
            with open(PROCESSED_USERS_FILE, "r") as file:
                return set(json.load(file))
        except Exception as e:
            logging.warning("Errore durante il caricamento degli user_id: %s", e)
    return set()

def save_processed_users(processed_users):
    """Salva gli user_id analizzati nel file."""
    try:
        with open(PROCESSED_USERS_FILE, "w") as file:
            json.dump(list(processed_users), file)
    except Exception as e:
        logging.warning("Errore durante il salvataggio degli user_id: %s", e)

def extract_post_data(post_data, thread_type="Thread"):
    try:
        post_id = post_data.get('pk')
        like_count = post_data.get('like_count', 0)
        caption = post_data.get('caption', {})
        caption_text = caption.get('text', "")

        return {
            'Post ID': post_id,
            'Thread Type': thread_type,
            'Like Count': like_count,
            'Caption Text': caption_text,
        }
    except Exception as e:
        return None

def process_data(ti, user_id):
    post_list = []
    try:
        data = ti.retrieve_user_threads(user_id)
        if not data or not data.get("data"):
            return []

        for thread in data["data"].get("mediaData", {}).get("threads", []):
            for threads_item in thread.get("thread_items", []):
                extracted_data = extract_post_data(threads_item.get("post", {}))
                if extracted_data:
                    post_list.append(extracted_data)

        logging.warning("Processed %d posts for User ID: %s", len(post_list), user_id)
        return post_list
    except Exception as e:
        # logging.warning("Error processing data for User ID %s: %s", user_id, e)
        return []

def update_user_data(data):
    ti = ThreadsInterface()

    # Carica gli user_id già analizzati
    processed_users = load_processed_users()
    processed_count = 0

    for user_id, user_info in data.items():
        if processed_count >= 40:  # Limite di 20 utenti
            break

        if user_id in processed_users:
            # logging.info("User ID %s già analizzato, saltando.", user_id)
            continue

        logging.warning("Processing user %s (processed count: %d)", user_id, processed_count)
        if not user_info.get("user_data"):  # Solo se user_data è vuoto
            user_threads = process_data(ti, user_id)
            if user_threads:
                user_info["user_data"] = user_threads
                processed_count += 1
        processed_users.add(user_id)

        followers = user_info.get("followers", [])
        if isinstance(followers, list):
            for follower in followers:
                follower_id = follower.get("user_id")
                if follower_id in processed_users:
                    # logging.info("Follower ID %s già analizzato, saltando.", follower_id)
                    continue
                if not follower.get("user_data") and follower_id:
                    follower_threads = process_data(ti, follower_id)
                    if follower_threads:
                        follower["user_data"] = follower_threads
                        processed_count += 1
                processed_users.add(follower_id)

    # Salva gli user_id analizzati
    save_processed_users(processed_users)
    return data

# %%
for _ in range(20):
    with open("../data/final_dataset.json", "rb") as f:
        json_data = json.load(f)
    updated_data = update_user_data(json_data)
    with open("../data/final_dataset.json", "w") as outfile:
        json.dump(updated_data, outfile, indent=4)
# Out:
# WARNING:root:Processing user 1695698303 (processed count: 0)
# WARNING:root:Processed 1 posts for User ID: 70135610001
# WARNING:root:Processed 0 posts for User ID: 58426355944
# WARNING:root:Processed 1 posts for User ID: 69547524413
# WARNING:root:Processed 1 posts for User ID: 866140883
# WARNING:root:Processed 0 posts for User ID: 60647646159
# WARNING:root:Processed 2 posts for User ID: 61837160638
# WARNING:root:Processed 3 posts for User ID: 25707907638
# WARNING:root:Processed 8 posts for User ID: 31364190611
# WARNING:root:Processed 2 posts for User ID: 4036972344
# WARNING:root:Processed 1 posts for User ID: 59527847968
# WARNING:root:Processed 16 posts for User ID: 49474247279
# WARNING:root:Processed 3 posts for User ID: 45648632744
# WARNING:root:Processed 0 posts for User ID: 44572339433
# WARNING:root:Processed 1 posts for User ID: 51906911723
# WARNING:root:Processed 3 posts for User ID: 60355321882
# WARNING:root:Processing user 53811662852 (processed count: 12)
# ...
