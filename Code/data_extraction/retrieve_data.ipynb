# %%
import logging
import pandas as pd
import os
import json

# %%
from retrieve_data_by_query import RetrieveDataByQuery
# t = RetrieveDataByQuery(sessionid="65955050144%3AsDI3oarlmsipI4%3A10%3AAYfZrHTizKd733ih8H3yTtTARkNxla7Jr5Fe_C14Iw")
# t = RetrieveDataByQuery(sessionid="67725660272%3AW741uU0WEqnpeU%3A11%3AAYc8uSJT5zhhAmFGrTsolApwMbEuOfyAr5P4hqX8IA")
# t = RetrieveDataByQuery(sessionid="72311449442%3AlUryE0KV76UBLs%3A27%3AAYcrmho9upEOXJN1UXfXFAcPBrxEthfQark1yarqDg")
# t = RetrieveDataByQuery(sessionid="72164089558%3ArAwUfcPDA9EFBe%3A11%3AAYfCrETIzCPGInwfJ21wGhSlRwbbdWTecG10Kd5GaA")
# t = RetrieveDataByQuery(sessionid="72164089558%3As83zYF4EnDh0UB%3A9%3AAYeSZtx6U69boU7q1yS7sXUdDgCwWuzZP-LYlG2hDg")
t = RetrieveDataByQuery(sessionid="72311449442%3A06XiI9UcgYrQNj%3A28%3AAYff3Vm7a8Xdcq5D3KpeACcLc9fiw9ums2V_FsU0qg")
# t.retrieve_follower_by_userid_after("62231305945", str(25 * 1))

# %%
query = "Artificial Intelligence"

# %%
def get_follower_data(data: list):
    try:
        return [
            {
                "pk": node.get("pk", ""),
                "username": node.get("username", ""),
                "follower_count": node.get("follower_count", "")
            }
            for d in data
            if (node := d.get("node", {}))
        ]
    except Exception as e:
        raise RuntimeError(f"Errore durante l'elaborazione dei dati dei follower: {e}")


progress_tracker = {}

def save_progress(userid: str, batch_number: int, results: list):
    """Salva il batch_number corrente e i risultati ottenuti per un determinato userid."""
    progress_tracker[userid] = {"batch_number": batch_number, "results": results}
    with open("progress2.json", "w") as f:
        json.dump(progress_tracker, f)

def load_progress(userid: str):
    """Carica il batch_number e i risultati salvati per un determinato userid."""
    try:
        with open("progress2.json", "r") as f:
            data = json.load(f)
            return data.get(userid, {"batch_number": 1, "results": []})
    except (FileNotFoundError, json.JSONDecodeError):
        return {"batch_number": 1, "results": []}
def remove_progress(userid: str):
    """Rimuove il progresso salvato per un determinato userid."""
    try:
        with open("progress2.json", "r") as f:
            data = json.load(f)
        
        if userid in data:
            del data[userid]
            with open("progress2.json", "w") as f:
                json.dump(data, f)
    except (FileNotFoundError, json.JSONDecodeError):
        pass
    
def get_all_follower(userid: str):
    progress = load_progress(userid)
    batch_number = progress["batch_number"]
    results = progress["results"]
    allpk = [res["pk"] for res in results]
    try:
        if batch_number == 1:
            response = t.retrieve_follower_by_userid(userid)
            data = response.get("data", {}).get("user", {}).get("followers", {})
            d_out = get_follower_data(data.get("edges", []))
            for res in d_out:
                allpk.append(res["pk"])
            results.extend(d_out)
            has_next_page = data.get("page_info", {}).get("has_next_page", False)
        else:
            has_next_page = True

        while has_next_page:
            try:
                print("Pagina:", batch_number)
                response = t.retrieve_follower_by_userid_after(userid, str(25 * batch_number))
                batch_number += 1
                data = response.get("data", {}).get("fetch__XDTUserDict", {}).get("followers", {})
                d_out = get_follower_data(data.get("edges", []))
                for res in d_out:
                    if res["pk"] in allpk:
                        remove_progress(userid)
                        return results
                    allpk.append(res["pk"])
                results.extend(d_out)
                
                has_next_page = data.get("page_info", {}).get("has_next_page", False)
                
                # Salva il progresso dopo ogni batch
                save_progress(userid, batch_number, results)
                
            except Exception as e:
                save_progress(userid, batch_number, results)  # Salva il batch e i risultati in caso di errore
                raise RuntimeError(f"Errore nel recupero della paginazione dei follower: {e}")
    
    except Exception as e:
        save_progress(userid, batch_number, results)  # Salva il batch e i risultati in caso di errore generale
        raise RuntimeError(f"Errore generale nel recupero dei follower per l'utente {userid}: {e}")
    remove_progress(userid)
    return results




def get_post_data(posts: list):
    results = []
    for post in posts:
        dati = post["node"]["thread"]["thread_items"]
        for p in dati:
            d = p['post']
            if int(d.get("like_count", 0)) < 100:
                continue
            userpk = d.get("user", {}).get("pk", "")
            caption = d.get("caption", {})
            caption_text = caption.get("text", "") if caption else ""
            if caption_text == "":
                continue
            results.append({
                "pk": d.get("pk", ""),
                "user_pk": userpk,
                "caption": caption_text,
                "like_count": int(d.get("like_count", 0)),
                "taken_at": d.get("taken_at", "")
            })
    return results

# %%
# results = []
# response = t.retrieve_thread_by_query(query)
# data = response.get("data", {}).get("searchResults", {})
# results.extend(get_post_data(data.get("edges", [])))
# has_next_page = data.get("page_info", {}).get("has_next_page", False)
# after = data.get("page_info", {}).get("end_cursor")
# i = 1000

# while has_next_page and i > 0:
#     response = t.retrieve_thread_by_query_after(query, after)
#     data = response.get("data", {}).get("searchResults", {})
#     results.extend(get_post_data(data.get("edges", [])))
#     has_next_page = data.get("page_info", {}).get("has_next_page", False)
#     after = data.get("page_info", {}).get("end_cursor")
#     i -= 1

# # Creazione del DataFrame
# df = pd.DataFrame(results)
# df.shape

# %%
# df.drop_duplicates(inplace=True)
# df['taken_at'] = pd.to_datetime(df['taken_at'], unit='s')
# df.to_csv("data.csv", index=False)

# %%
df = pd.read_csv("data_parte2.csv")
df['user_pk'] = df['user_pk'].astype(str)
unique_user_pk = df['user_pk'].unique()
len(unique_user_pk)
# Out:
# 293

# %%
def load_processed_users(file_path):
    if os.path.exists(file_path):
        logging.info(f"Loading processed users from {file_path}")
        df = pd.read_csv(file_path)
        df['user_pk'] = df['user_pk'].astype(str)
        return set(df['user_pk'].tolist())
    return set()

def save_to_csv(df, file_path):
    try:
        if os.path.exists(file_path):
            df.to_csv(file_path, mode='a', header=False, index=False)
        else:
            df.to_csv(file_path, index=False)
        logging.info(f"Saved {len(df)} records to {file_path}")
    except Exception as e:
        logging.error(f"Error saving data to {file_path}: {e}")
        
csv_file = "followers_data2.csv"
processed_users = load_processed_users(csv_file)

# %%
def fetch_followers(pk):
    print(f"Fetching followers for user_pk: {pk}")
    try:
        follower_data = get_all_follower(pk)
        return [
            {
                "user_pk": pk,
                "follower_pk": follower["pk"],
                "follower_username": follower["username"],
                "follower_count": follower["follower_count"]
            }
            for follower in follower_data
        ]
    except Exception as e:
        logging.error(f"Error fetching followers for {pk}: {e}")
        return None



follower_list = []
batch_size = 1


print("Starting follower data collection")
for user_pk in unique_user_pk:
    if user_pk in processed_users:
        print(f"Skipping already processed user_pk: {user_pk}")
        continue
    
    processed_users.update([user_pk])
    results = fetch_followers(user_pk)
    if results is None:
        break
    follower_list.extend(results)
    
    if follower_list:
        print(f"Processing batch of {len(follower_list)} followers")
        follower_df = pd.DataFrame(follower_list)
        save_to_csv(follower_df, csv_file)
        follower_list = []

if follower_list:
    print(f"Saving remaining {len(follower_list)} followers")
    follower_df = pd.DataFrame(follower_list)
    save_to_csv(follower_df, csv_file)

print("Follower data collection completed")
# Out:
# Starting follower data collection
# Skipping already processed user_pk: 192592722
# Skipping already processed user_pk: 259533357
# Skipping already processed user_pk: 387960
# Skipping already processed user_pk: 60903176602
# Skipping already processed user_pk: 69724808842
# Skipping already processed user_pk: 5642593129
# Skipping already processed user_pk: 25004361
# Skipping already processed user_pk: 54052706
# Skipping already processed user_pk: 30628914796
# Skipping already processed user_pk: 11630601130
# Skipping already processed user_pk: 18371369
# Skipping already processed user_pk: 60837322123
# Skipping already processed user_pk: 25058521708
# Skipping already processed user_pk: 508545432
# Skipping already processed user_pk: 1502777818
# Skipping already processed user_pk: 40472391
# Skipping already processed user_pk: 2267199523
# Skipping already processed user_pk: 49573589494
# Skipping already processed user_pk: 53223130121
# Skipping already processed user_pk: 22181915186
# Skipping already processed user_pk: 3096331
# Skipping already processed user_pk: 223999684
# Skipping already processed user_pk: 374099
# Skipping already processed user_pk: 10206720
# Skipping already processed user_pk: 42058280528
# Skipping already processed user_pk: 2754610
# Skipping already processed user_pk: 2994846754
# Skipping already processed user_pk: 35553152276
# Skipping already processed user_pk: 61534656053
# Skipping already processed user_pk: 16628016323
# Skipping already processed user_pk: 27892923483
# Skipping already processed user_pk: 55893720046
# Skipping already processed user_pk: 29590649841
# Skipping already processed user_pk: 56372602545
# Skipping already processed user_pk: 60727554074
# Skipping already processed user_pk: 1375237296
# Skipping already processed user_pk: 6234915356
# Skipping already processed user_pk: 46560360663
# Skipping already processed user_pk: 1091359
# Skipping already processed user_pk: 35234674384
# Skipping already processed user_pk: 19018585
# Skipping already processed user_pk: 1624593034
# Skipping already processed user_pk: 1743925149
# Skipping already processed user_pk: 5378803501
# Skipping already processed user_pk: 19625619
# Skipping already processed user_pk: 66374082374
# Skipping already processed user_pk: 6240064298
# Skipping already processed user_pk: 3536815
# Skipping already processed user_pk: 60832949871
# Skipping already processed user_pk: 37149867
# Skipping already processed user_pk: 56536966874
# Skipping already processed user_pk: 13360084798
# Skipping already processed user_pk: 1936196741
# Skipping already processed user_pk: 325281215
# Skipping already processed user_pk: 10750374648
# Skipping already processed user_pk: 9192944
# Skipping already processed user_pk: 6169156
# Skipping already processed user_pk: 2096157072
# Skipping already processed user_pk: 10014026275
# Skipping already processed user_pk: 20419305
# Skipping already processed user_pk: 247784713
# Skipping already processed user_pk: 1726704720
# Skipping already processed user_pk: 1819517023
# Skipping already processed user_pk: 30472835
# Skipping already processed user_pk: 1822638
# Skipping already processed user_pk: 1367054971
# Skipping already processed user_pk: 247898173
# Skipping already processed user_pk: 5429930915
# Skipping already processed user_pk: 1960366
# Skipping already processed user_pk: 5847078150
# Skipping already processed user_pk: 194150195
# Skipping already processed user_pk: 253854350
# Skipping already processed user_pk: 244284
# Skipping already processed user_pk: 45942335378
# Skipping already processed user_pk: 52601847031
# Skipping already processed user_pk: 39972782
# Skipping already processed user_pk: 6050066
# Skipping already processed user_pk: 5957045941
# Skipping already processed user_pk: 327693598
# Skipping already processed user_pk: 26750800
# Skipping already processed user_pk: 6731123325
# Skipping already processed user_pk: 1269598
# Skipping already processed user_pk: 4962574585
# Skipping already processed user_pk: 8437367532
# Skipping already processed user_pk: 399036128
# Skipping already processed user_pk: 8666406127
# Skipping already processed user_pk: 4293712500
# Skipping already processed user_pk: 49022532563
# Skipping already processed user_pk: 37108691637
# Skipping already processed user_pk: 1472031107
# Skipping already processed user_pk: 2293372650
# Skipping already processed user_pk: 5533620200
# Skipping already processed user_pk: 2713455141
# Skipping already processed user_pk: 71498045389
# Skipping already processed user_pk: 3578301928
# Skipping already processed user_pk: 576676423
# Skipping already processed user_pk: 3544549933
# Skipping already processed user_pk: 217723373
# Skipping already processed user_pk: 19561910521
# Skipping already processed user_pk: 7971150203
# Skipping already processed user_pk: 4245421081
# Skipping already processed user_pk: 50850562069
# Skipping already processed user_pk: 900035468
# Skipping already processed user_pk: 58674998540
# Skipping already processed user_pk: 388706042
# Skipping already processed user_pk: 12154319635
# Skipping already processed user_pk: 7430277125
# Skipping already processed user_pk: 20288001371
# Skipping already processed user_pk: 32725933
# Skipping already processed user_pk: 46089946650
# Skipping already processed user_pk: 1437149
# Skipping already processed user_pk: 32942248
# Skipping already processed user_pk: 52692551603
# Skipping already processed user_pk: 62191713037
# Skipping already processed user_pk: 45270637943
# Skipping already processed user_pk: 18418368280
# Skipping already processed user_pk: 2138185630
# Skipping already processed user_pk: 63879170807
# Skipping already processed user_pk: 329234000
# Skipping already processed user_pk: 221900711
# Skipping already processed user_pk: 327123238
# Skipping already processed user_pk: 3038883670
# Skipping already processed user_pk: 2258626034
# Skipping already processed user_pk: 20516122
# Skipping already processed user_pk: 1956292712
# Skipping already processed user_pk: 480609945
# Skipping already processed user_pk: 1799585667
# Skipping already processed user_pk: 66809578370
# Skipping already processed user_pk: 2535539528
# Skipping already processed user_pk: 2000074319
# Skipping already processed user_pk: 39370791
# Skipping already processed user_pk: 6900906840
# Skipping already processed user_pk: 1069800347
# Skipping already processed user_pk: 58134309921
# Skipping already processed user_pk: 59073676932
# Skipping already processed user_pk: 403634307
# Skipping already processed user_pk: 38737749073
# Skipping already processed user_pk: 490713653
# Skipping already processed user_pk: 2054830373
# Skipping already processed user_pk: 44822664242
# Skipping already processed user_pk: 65186239907
# Skipping already processed user_pk: 6790395260
# Skipping already processed user_pk: 51300651222
# Skipping already processed user_pk: 22956306067
# Skipping already processed user_pk: 31795313
# Skipping already processed user_pk: 7716851564
# Skipping already processed user_pk: 1543999420
# Skipping already processed user_pk: 28984144473
# Skipping already processed user_pk: 59783233970
# Skipping already processed user_pk: 62168385600
# Skipping already processed user_pk: 4634659252
# Skipping already processed user_pk: 45828823
# Skipping already processed user_pk: 68126431458
# Skipping already processed user_pk: 67382382307
# Skipping already processed user_pk: 58751456078
# Skipping already processed user_pk: 1573953359
# Skipping already processed user_pk: 24538412
# Skipping already processed user_pk: 44972453599
# Skipping already processed user_pk: 440419613
# Skipping already processed user_pk: 558170
# Skipping already processed user_pk: 753136687
# Skipping already processed user_pk: 47322064107
# Skipping already processed user_pk: 8629875
# Skipping already processed user_pk: 793422285
# Skipping already processed user_pk: 58641706122
# Skipping already processed user_pk: 2318374052
# Skipping already processed user_pk: 1186758566
# Skipping already processed user_pk: 1270785018
# Skipping already processed user_pk: 460132935
# Skipping already processed user_pk: 60177271189
# Skipping already processed user_pk: 1090108724
# Skipping already processed user_pk: 1152137
# Skipping already processed user_pk: 182589350
# Skipping already processed user_pk: 45412089130
# Skipping already processed user_pk: 609510215
# Skipping already processed user_pk: 48184076748
# Skipping already processed user_pk: 6157304661
# Skipping already processed user_pk: 2213013115
# Skipping already processed user_pk: 5630155732
# Skipping already processed user_pk: 1491998349
# Skipping already processed user_pk: 3919308273
# Skipping already processed user_pk: 2144532908
# Skipping already processed user_pk: 70995803294
# Skipping already processed user_pk: 8549348319
# Skipping already processed user_pk: 47735856363
# Skipping already processed user_pk: 9121638
# Skipping already processed user_pk: 957969816
# Skipping already processed user_pk: 30898605962
# Skipping already processed user_pk: 15124115
# Skipping already processed user_pk: 66592146395
# Skipping already processed user_pk: 33762
# Skipping already processed user_pk: 4970402256
# Skipping already processed user_pk: 2071465290
# Skipping already processed user_pk: 3994335279
# Skipping already processed user_pk: 175341077
# Skipping already processed user_pk: 4034608
# Skipping already processed user_pk: 1518167765
# Skipping already processed user_pk: 3941842990
# Skipping already processed user_pk: 54663962627
# Skipping already processed user_pk: 193578318
# Skipping already processed user_pk: 1199148703
# Skipping already processed user_pk: 636489245
# Skipping already processed user_pk: 1127989442
# Skipping already processed user_pk: 37137221203
# Skipping already processed user_pk: 45086165924
# Skipping already processed user_pk: 1622615488
# Skipping already processed user_pk: 394302070
# Skipping already processed user_pk: 29903669548
# Skipping already processed user_pk: 3965953452
# Skipping already processed user_pk: 11380087
# Skipping already processed user_pk: 71856594851
# Skipping already processed user_pk: 1409496993
# Skipping already processed user_pk: 49559458071
# Skipping already processed user_pk: 47638095399
# Skipping already processed user_pk: 6711361230
# Skipping already processed user_pk: 2065557811
# Skipping already processed user_pk: 1013395
# Skipping already processed user_pk: 53462333161
# Skipping already processed user_pk: 3904954498
# Skipping already processed user_pk: 57976728218
# Skipping already processed user_pk: 1435944845
# Skipping already processed user_pk: 1508204760
# Skipping already processed user_pk: 8608990298
# Skipping already processed user_pk: 438959421
# Skipping already processed user_pk: 2956624348
# Skipping already processed user_pk: 45814320760
# Skipping already processed user_pk: 18133069
# Skipping already processed user_pk: 58458063887
# Skipping already processed user_pk: 60988329648
# Skipping already processed user_pk: 51548613427
# Skipping already processed user_pk: 3882838021
# Skipping already processed user_pk: 815053
# Skipping already processed user_pk: 46218147
# Skipping already processed user_pk: 49977544
# Skipping already processed user_pk: 60762270900
# Skipping already processed user_pk: 11570754
# Skipping already processed user_pk: 48612718859
# Skipping already processed user_pk: 31584165605
# Skipping already processed user_pk: 35297610726
# Skipping already processed user_pk: 295078956
# Skipping already processed user_pk: 6946980135
# Skipping already processed user_pk: 7818732466
# Skipping already processed user_pk: 58840879290
# Skipping already processed user_pk: 52677658881
# Skipping already processed user_pk: 1678378118
# Skipping already processed user_pk: 30645922
# Skipping already processed user_pk: 51267946797
# Skipping already processed user_pk: 5162610
# Skipping already processed user_pk: 67629333929
# Skipping already processed user_pk: 10924172884
# Skipping already processed user_pk: 30975209
# Skipping already processed user_pk: 11613233563
# Skipping already processed user_pk: 442507214
# Skipping already processed user_pk: 3176205778
# Skipping already processed user_pk: 5756868629
# Skipping already processed user_pk: 5718095958
# Skipping already processed user_pk: 59821811343
# Skipping already processed user_pk: 643621418
# Skipping already processed user_pk: 67886089765
# Skipping already processed user_pk: 268693981
# Skipping already processed user_pk: 270581312
# Skipping already processed user_pk: 520197851
# Skipping already processed user_pk: 27993432248
# Skipping already processed user_pk: 1072450671
# Skipping already processed user_pk: 454168786
# Skipping already processed user_pk: 41114146
# Skipping already processed user_pk: 265121
# Skipping already processed user_pk: 48269831461
# Skipping already processed user_pk: 1392107282
# Skipping already processed user_pk: 47798957458
# Skipping already processed user_pk: 27851184
# Skipping already processed user_pk: 3629345432
# Skipping already processed user_pk: 61705927056
# Skipping already processed user_pk: 50446070550
# Skipping already processed user_pk: 1146033485
# Skipping already processed user_pk: 51778342737
# Skipping already processed user_pk: 129231
# Skipping already processed user_pk: 46207912257
# Skipping already processed user_pk: 1924840
# Skipping already processed user_pk: 57889997467
# Skipping already processed user_pk: 50663854349
# Skipping already processed user_pk: 30792132
# Skipping already processed user_pk: 37148231
# Skipping already processed user_pk: 192885368
# Skipping already processed user_pk: 6769850
# Skipping already processed user_pk: 28911734608
# Skipping already processed user_pk: 60788056438
# Skipping already processed user_pk: 371103980
# Skipping already processed user_pk: 2924603762
# Skipping already processed user_pk: 1551970443
# Skipping already processed user_pk: 58712495227
# Skipping already processed user_pk: 2043388800
# Skipping already processed user_pk: 62231305945
# Follower data collection completed

# %%
df1 = pd.read_csv("followers_data2.csv")
df_count= df1.drop_duplicates().groupby("user_pk").count()
print(df_count.shape)
df_count
# Out:
# (293, 3)
#              follower_pk  follower_username  follower_count
# user_pk
# 33762                725                725             725
# 129231              3002               3002            3002
# 244284                49                 49              49
# 265121                49                 49              49
# 374099                49                 49              49
# ...                  ...                ...             ...
# 68126431458         1337               1337            1337
# 69724808842          497                497             497
# 70995803294          365                365             365
# 71498045389          180                180             180
# 71856594851          880                880             880
#
# [293 rows x 3 columns]

# %%
df1 = pd.read_csv("followers_data2.csv")
df1 = df1.drop_duplicates()
df1
df1.to_csv("followers_data2.csv")
