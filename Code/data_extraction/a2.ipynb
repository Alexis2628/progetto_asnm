# %%
import logging
import pandas as pd
import os
import json

# %%
from retrieve_data_by_query import RetrieveDataByQuery
# t = RetrieveDataByQuery(sessionid="65955050144%3AsDI3oarlmsipI4%3A10%3AAYfZrHTizKd733ih8H3yTtTARkNxla7Jr5Fe_C14Iw")
# t = RetrieveDataByQuery(sessionid="72311449442%3AH6DGmjoHPSEFBt%3A9%3AAYfhjmVCEbQqQuRrNtjfPFjsWGdPMJAlrnjGYEAV2A")
# t = RetrieveDataByQuery(sessionid="71968904949%3AnasVvoUgWlaAh9%3A24%3AAYd4CsZNXogQYrfEcx5z1MFKBGij2-m8LTppQKPwfA")
t = RetrieveDataByQuery(sessionid="72311449442%3A06XiI9UcgYrQNj%3A28%3AAYff3Vm7a8Xdcq5D3KpeACcLc9fiw9ums2V_FsU0qg")
# t.retrieve_follower_by_userid("60653058465")
# t.retrieve_follower_by_userid_after("60653058465", str(25 * 1))
# Out:
# {'errors': [{'message': 'execution error',
#    'path': ['user'],
#    'severity': 'CRITICAL'}],
#  'data': None,
#  'extensions': {'is_final': True},
#  'status': 'ok'}

# %%
query = "Artificial Intelligence"

# %%
def get_follower_data(data: list):
    try:
        return [
            {
                "pk": node.get("pk", ""),
                "username": node.get("username", ""),
                "follower_count": node.get("follower_count", "")
            }
            for d in data
            if (node := d.get("node", {}))
        ]
    except Exception as e:
        raise RuntimeError(f"Errore durante l'elaborazione dei dati dei follower: {e}")


progress_tracker = {}

def save_progress(userid: str, batch_number: int, results: list):
    """Salva il batch_number corrente e i risultati ottenuti per un determinato userid."""
    progress_tracker[userid] = {"batch_number": batch_number, "results": results}
    with open("progress3.json", "w") as f:
        json.dump(progress_tracker, f)

def load_progress(userid: str):
    """Carica il batch_number e i risultati salvati per un determinato userid."""
    try:
        with open("progress3.json", "r") as f:
            data = json.load(f)
            return data.get(userid, {"batch_number": 1, "results": []})
    except (FileNotFoundError, json.JSONDecodeError):
        return {"batch_number": 1, "results": []}
def remove_progress(userid: str):
    """Rimuove il progresso salvato per un determinato userid."""
    try:
        with open("progress3.json", "r") as f:
            data = json.load(f)
        
        if userid in data:
            del data[userid]
            with open("progress3.json", "w") as f:
                json.dump(data, f)
    except (FileNotFoundError, json.JSONDecodeError):
        pass
    
def get_all_follower(userid: str):
    progress = load_progress(userid)
    batch_number = progress["batch_number"]
    results = progress["results"]
    allpk = [res["pk"] for res in results]
    try:
        if batch_number == 1:
            response = t.retrieve_follower_by_userid(userid)
            data = response.get("data", {}).get("user", {}).get("followers", {})
            d_out = get_follower_data(data.get("edges", []))
            for res in d_out:
                allpk.append(res["pk"])
            results.extend(d_out)
            has_next_page = data.get("page_info", {}).get("has_next_page", False)
        else:
            has_next_page = True

        while has_next_page:
            try:
                print("Pagina:", batch_number)
                response = t.retrieve_follower_by_userid_after(userid, str(25 * batch_number))
                batch_number += 1
                data = response.get("data", {}).get("fetch__XDTUserDict", {}).get("followers", {})
                d_out = get_follower_data(data.get("edges", []))
                for res in d_out:
                    if res["pk"] in allpk:
                        remove_progress(userid)
                        return results
                    allpk.append(res["pk"])
                results.extend(d_out)
                
                has_next_page = data.get("page_info", {}).get("has_next_page", False)
                
                # Salva il progresso dopo ogni batch
                save_progress(userid, batch_number, results)
                
            except Exception as e:
                save_progress(userid, batch_number, results)  # Salva il batch e i risultati in caso di errore
                raise RuntimeError(f"Errore nel recupero della paginazione dei follower: {e}")
    
    except Exception as e:
        save_progress(userid, batch_number, results)  # Salva il batch e i risultati in caso di errore generale
        raise RuntimeError(f"Errore generale nel recupero dei follower per l'utente {userid}: {e}")
    remove_progress(userid)
    return results




def get_post_data(posts: list):
    results = []
    for post in posts:
        dati = post["node"]["thread"]["thread_items"]
        for p in dati:
            d = p['post']
            if int(d.get("like_count", 0)) < 100:
                continue
            userpk = d.get("user", {}).get("pk", "")
            caption = d.get("caption", {})
            caption_text = caption.get("text", "") if caption else ""
            if caption_text == "":
                continue
            results.append({
                "pk": d.get("pk", ""),
                "user_pk": userpk,
                "caption": caption_text,
                "like_count": int(d.get("like_count", 0)),
                "taken_at": d.get("taken_at", "")
            })
    return results

# %%
# results = []
# response = t.retrieve_thread_by_query(query)
# data = response.get("data", {}).get("searchResults", {})
# results.extend(get_post_data(data.get("edges", [])))
# has_next_page = data.get("page_info", {}).get("has_next_page", False)
# after = data.get("page_info", {}).get("end_cursor")
# i = 1000

# while has_next_page and i > 0:
#     response = t.retrieve_thread_by_query_after(query, after)
#     data = response.get("data", {}).get("searchResults", {})
#     results.extend(get_post_data(data.get("edges", [])))
#     has_next_page = data.get("page_info", {}).get("has_next_page", False)
#     after = data.get("page_info", {}).get("end_cursor")
#     i -= 1

# # Creazione del DataFrame
# df = pd.DataFrame(results)
# df.shape

# %%
# df.drop_duplicates(inplace=True)
# df['taken_at'] = pd.to_datetime(df['taken_at'], unit='s')
# df.to_csv("data.csv", index=False)

# %%
df = pd.read_csv("data_parte3.csv")
df['user_pk'] = df['user_pk'].astype(str)
unique_user_pk = df['user_pk'].unique()
len(unique_user_pk)
# Out:
# 378

# %%
def load_processed_users(file_path):
    if os.path.exists(file_path):
        logging.info(f"Loading processed users from {file_path}")
        df = pd.read_csv(file_path)
        df['user_pk'] = df['user_pk'].astype(str)
        return set(df['user_pk'].tolist())
    return set()

def save_to_csv(df, file_path):
    try:
        if os.path.exists(file_path):
            df.to_csv(file_path, mode='a', header=False, index=False)
        else:
            df.to_csv(file_path, index=False)
        logging.info(f"Saved {len(df)} records to {file_path}")
    except Exception as e:
        logging.error(f"Error saving data to {file_path}: {e}")
        
csv_file = "followers_data3.csv"
processed_users = load_processed_users(csv_file)

# %%
def fetch_followers(pk):
    print(f"Fetching followers for user_pk: {pk}")
    try:
        follower_data = get_all_follower(pk)
        return [
            {
                "user_pk": pk,
                "follower_pk": follower["pk"],
                "follower_username": follower["username"],
                "follower_count": follower["follower_count"]
            }
            for follower in follower_data
        ]
    except Exception as e:
        logging.error(f"Error fetching followers for {pk}: {e}")
        return None



follower_list = []
batch_size = 1


print("Starting follower data collection")
for user_pk in unique_user_pk:
    if user_pk in processed_users:
        print(f"Skipping already processed user_pk: {user_pk}")
        continue
    
    processed_users.update([user_pk])
    results = fetch_followers(user_pk)
    if results is None:
        break
    follower_list.extend(results)
    
    if follower_list:
        print(f"Processing batch of {len(follower_list)} followers")
        follower_df = pd.DataFrame(follower_list)
        save_to_csv(follower_df, csv_file)
        follower_list = []

if follower_list:
    print(f"Saving remaining {len(follower_list)} followers")
    follower_df = pd.DataFrame(follower_list)
    save_to_csv(follower_df, csv_file)

print("Follower data collection completed")
# Out:
# Starting follower data collection
# Skipping already processed user_pk: 1822638
# Skipping already processed user_pk: 16024045660
# Skipping already processed user_pk: 11630601130
# Skipping already processed user_pk: 1517077572
# Skipping already processed user_pk: 30898605962
# Skipping already processed user_pk: 25194715
# Skipping already processed user_pk: 58693069230
# Skipping already processed user_pk: 357909564
# Skipping already processed user_pk: 1074846
# Skipping already processed user_pk: 59902844185
# Skipping already processed user_pk: 42058280528
# Skipping already processed user_pk: 47871905591
# Skipping already processed user_pk: 1701574
# Skipping already processed user_pk: 12992325
# Skipping already processed user_pk: 3073899690
# Skipping already processed user_pk: 27622983
# Skipping already processed user_pk: 10193147479
# Skipping already processed user_pk: 55420269
# Skipping already processed user_pk: 5656258976
# Skipping already processed user_pk: 1956292712
# Skipping already processed user_pk: 208499143
# Skipping already processed user_pk: 295564582
# Skipping already processed user_pk: 192592722
# Skipping already processed user_pk: 558170
# Skipping already processed user_pk: 1347193480
# Skipping already processed user_pk: 1624593034
# Skipping already processed user_pk: 2213013115
# Skipping already processed user_pk: 327693598
# Skipping already processed user_pk: 2754610
# Skipping already processed user_pk: 69724808842
# Skipping already processed user_pk: 10924172884
# Skipping already processed user_pk: 64740276628
# Skipping already processed user_pk: 1641677778
# Skipping already processed user_pk: 10960005016
# Skipping already processed user_pk: 61752853814
# Skipping already processed user_pk: 1743925149
# Skipping already processed user_pk: 35234674384
# Skipping already processed user_pk: 42371579584
# Skipping already processed user_pk: 231260407
# Skipping already processed user_pk: 3459581312
# Skipping already processed user_pk: 60727554074
# Skipping already processed user_pk: 2442881
# Skipping already processed user_pk: 3124837466
# Skipping already processed user_pk: 32822679069
# Skipping already processed user_pk: 34545258
# Skipping already processed user_pk: 51494287566
# Skipping already processed user_pk: 1957756995
# Skipping already processed user_pk: 70981082737
# Skipping already processed user_pk: 60416752048
# Skipping already processed user_pk: 61102128227
# Skipping already processed user_pk: 44134409
# Skipping already processed user_pk: 19720490
# Skipping already processed user_pk: 65534338753
# Skipping already processed user_pk: 424626609
# Skipping already processed user_pk: 6056471754
# Skipping already processed user_pk: 54493827605
# Skipping already processed user_pk: 259533357
# Skipping already processed user_pk: 49573589494
# Skipping already processed user_pk: 1687848
# Skipping already processed user_pk: 45438067904
# Skipping already processed user_pk: 59148354604
# Skipping already processed user_pk: 3910607774
# Skipping already processed user_pk: 272128451
# Skipping already processed user_pk: 66173660653
# Skipping already processed user_pk: 1091359
# Skipping already processed user_pk: 6946980135
# Skipping already processed user_pk: 17616713688
# Skipping already processed user_pk: 4140608
# Skipping already processed user_pk: 1543999420
# Skipping already processed user_pk: 60601877613
# Skipping already processed user_pk: 58768100386
# Skipping already processed user_pk: 19018585
# Skipping already processed user_pk: 520197851
# Skipping already processed user_pk: 4159632083
# Skipping already processed user_pk: 39643192594
# Skipping already processed user_pk: 217723373
# Skipping already processed user_pk: 4634659252
# Skipping already processed user_pk: 1199148703
# Skipping already processed user_pk: 3552605939
# Skipping already processed user_pk: 44811065685
# Skipping already processed user_pk: 1173750895
# Skipping already processed user_pk: 50927065299
# Skipping already processed user_pk: 399036128
# Skipping already processed user_pk: 1759341862
# Skipping already processed user_pk: 46218147
# Skipping already processed user_pk: 3134401744
# Skipping already processed user_pk: 65734726050
# Skipping already processed user_pk: 374099
# Skipping already processed user_pk: 19837372888
# Skipping already processed user_pk: 42950869
# Skipping already processed user_pk: 58134309921
# Skipping already processed user_pk: 21723588
# Skipping already processed user_pk: 1611708271
# Skipping already processed user_pk: 3189157336
# Skipping already processed user_pk: 247784713
# Skipping already processed user_pk: 62231305945
# Skipping already processed user_pk: 60769328359
# Skipping already processed user_pk: 11380087
# Skipping already processed user_pk: 1072450671
# Skipping already processed user_pk: 1047914188
# Skipping already processed user_pk: 38737749073
# Skipping already processed user_pk: 35297610726
# Skipping already processed user_pk: 244885446
# Skipping already processed user_pk: 1566415294
# Skipping already processed user_pk: 59949824724
# Skipping already processed user_pk: 6286444
# Skipping already processed user_pk: 5630155732
# Skipping already processed user_pk: 36017971447
# Skipping already processed user_pk: 5980587082
# Skipping already processed user_pk: 1482438469
# Skipping already processed user_pk: 1660373030
# Skipping already processed user_pk: 50122295913
# Skipping already processed user_pk: 65117952636
# Skipping already processed user_pk: 265121
# Skipping already processed user_pk: 5954698659
# Skipping already processed user_pk: 51778342737
# Skipping already processed user_pk: 3158587882
# Skipping already processed user_pk: 4710578338
# Skipping already processed user_pk: 291916767
# Skipping already processed user_pk: 95561
# Skipping already processed user_pk: 10159984641
# Skipping already processed user_pk: 2670586414
# Skipping already processed user_pk: 13209447199
# Skipping already processed user_pk: 175341077
# Skipping already processed user_pk: 2119997
# Skipping already processed user_pk: 30855355
# Skipping already processed user_pk: 5480416234
# Skipping already processed user_pk: 49978946
# Skipping already processed user_pk: 7185791349
# Skipping already processed user_pk: 48283353082
# Skipping already processed user_pk: 57715779752
# Skipping already processed user_pk: 245853115
# Skipping already processed user_pk: 10687344986
# Skipping already processed user_pk: 58840879290
# Skipping already processed user_pk: 284399
# Skipping already processed user_pk: 440276698
# Skipping already processed user_pk: 1258618
# Skipping already processed user_pk: 5596452091
# Skipping already processed user_pk: 3239003105
# Skipping already processed user_pk: 1152137
# Fetching followers for user_pk: 60653058465
# ERROR:root:Error fetching followers for 60653058465: Errore generale nel recupero dei follower per l'utente 60653058465: 'NoneType' object has no attribute 'get'
# Follower data collection completed

# %%
df1 = pd.read_csv("followers_data3.csv")
df_count= df1.drop_duplicates().groupby("user_pk").count()
print(df_count.shape)
df_count
# Out:
# (373, 3)
#              follower_pk  follower_username  follower_count
# user_pk
# 95561                 47                 47              47
# 265121                49                 49              49
# 284399                50                 50              50
# 314216                50                 50              50
# 374099                50                 50              50
# ...                  ...                ...             ...
# 70931105344          239                239             239
# 70981082737          249                249             249
# 71128024083           25                 25              25
# 71561257313           25                 25              25
# 72243336160           50                 50              50
#
# [373 rows x 3 columns]
