# %%
from threads_interface import ThreadsInterface  # Assicurati che questo sia il percorso corretto

threads_interface = ThreadsInterface()
response = threads_interface.retrieve_thread_by_query("#AIBusiness")

# %%
response
# Out:
# {'data': {'searchResults': {'inform_module': None,
#    'edges': [{'node': {'thread': {'thread_header_context': None,
#        'thread_items': [{'post': {'pk': '3473877087986574562',
#           'user': {'friendship_status': None,
#            'id': '48739568220',
#            'eligible_for_text_app_activation_badge': None,
#            'hide_text_app_activation_badge_on_text_app': False,
#            '_is__TOnXDTUserDict__0': 'XDTUserDict',
#            'pk': '48739568220',
#            'transparency_label': None,
#            '_is__TOnXDTUserDict__12': 'XDTUserDict',
#            'transparency_product': None,
#            'transparency_product_enabled': False,
#            '_is__TOnXDTUserDict__13': 'XDTUserDict',
#            'is_verified': False,
#            'username': 'vivekecom',
#            '_is__TOnXDTUserDict__14': 'XDTUserDict',
#            '_is__TOnXDTUserDict__15': 'XDTUserDict',
#            '_is__TOnXDTUserDict__16': 'XDTUserDict',
# ...
